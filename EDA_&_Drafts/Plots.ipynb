# %%
# Initial imports.
import pandas as pd
from path import Path
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
import seaborn as sns

# %%
wine_df = pd.read_csv(Path("wine2.csv"),index_col=0)
wine_df.head()
# Out:
#                volatile_acidity  citric_acid  residual_sugar  chlorides  \
# fixed_acidity
# 7.4                        0.70         0.00             1.9      0.076
# 7.8                        0.88         0.00             2.6      0.098
# 7.8                        0.76         0.04             2.3      0.092
# 11.2                       0.28         0.56             1.9      0.075
# 7.4                        0.66         0.00             1.8      0.075
#
#                free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# fixed_acidity
# 7.4                           11.0                  34.0   0.9978  3.51
# 7.8                           25.0                  67.0   0.9968  3.20
# 7.8                           15.0                  54.0   0.9970  3.26
# 11.2                          17.0                  60.0   0.9980  3.16
# 7.4                           13.0                  40.0   0.9978  3.51
#
#                sulphates  alcohol  quality  type
# fixed_acidity
# ...

# %%
wine_df= wine_df.drop_duplicates()
wine_df.head()
# Out:
#                volatile_acidity  citric_acid  residual_sugar  chlorides  \
# fixed_acidity
# 7.4                        0.70         0.00             1.9      0.076
# 7.8                        0.88         0.00             2.6      0.098
# 7.8                        0.76         0.04             2.3      0.092
# 11.2                       0.28         0.56             1.9      0.075
# 7.4                        0.66         0.00             1.8      0.075
#
#                free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# fixed_acidity
# 7.4                           11.0                  34.0   0.9978  3.51
# 7.8                           25.0                  67.0   0.9968  3.20
# 7.8                           15.0                  54.0   0.9970  3.26
# 11.2                          17.0                  60.0   0.9980  3.16
# 7.4                           13.0                  40.0   0.9978  3.51
#
#                sulphates  alcohol  quality  type
# fixed_acidity
# ...

# %%
X = wine_df.copy()
X = X.drop("type", axis=1)
X.head()
# Out:
#                volatile_acidity  citric_acid  residual_sugar  chlorides  \
# fixed_acidity
# 7.4                        0.70         0.00             1.9      0.076
# 7.8                        0.88         0.00             2.6      0.098
# 7.8                        0.76         0.04             2.3      0.092
# 11.2                       0.28         0.56             1.9      0.075
# 7.4                        0.66         0.00             1.8      0.075
#
#                free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# fixed_acidity
# 7.4                           11.0                  34.0   0.9978  3.51
# 7.8                           25.0                  67.0   0.9968  3.20
# 7.8                           15.0                  54.0   0.9970  3.26
# 11.2                          17.0                  60.0   0.9980  3.16
# 7.4                           13.0                  40.0   0.9978  3.51
#
#                sulphates  alcohol  quality
# fixed_acidity
# ...

# %%
wine_df.loc[wine_df["type"] == 0, "type"] = 'red'
wine_df.loc[wine_df["type"] == 1, "type"] = 'white'
wine_df.tail()
# Out:
#                volatile_acidity  citric_acid  residual_sugar  chlorides  \
# fixed_acidity
# 6.2                        0.21         0.29             1.6      0.039
# 6.6                        0.32         0.36             8.0      0.047
# 6.5                        0.24         0.19             1.2      0.041
# 5.5                        0.29         0.30             1.1      0.022
# 6.0                        0.21         0.38             0.8      0.020
#
#                free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# fixed_acidity
# 6.2                           24.0                  92.0  0.99114  3.27
# 6.6                           57.0                 168.0  0.99490  3.15
# 6.5                           30.0                 111.0  0.99254  2.99
# 5.5                           20.0                 110.0  0.98869  3.34
# 6.0                           22.0                  98.0  0.98941  3.26
#
#                sulphates  alcohol  quality   type
# fixed_acidity
# ...

# %%
sns.violinplot(data=wine_df, x="quality", y="alcohol", hue="type", split=True)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='alcohol'>

# %%
sns.violinplot(data=wine_df, x="quality", y="density", hue="type", split=True)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='density'>

# %%
sns.violinplot(data=wine_df, x="quality", y="chlorides", hue="type", split=True)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='chlorides'>
